# %%
pwd
# Out:
# 'C:\\Users\\Jack Sparrow'

# %%
import pandas as pd
import numpy as np
import pylab
import matplotlib.pyplot as plt

# %%
# Using pandas to import data from Excel

df = pd.read_csv('Photoelectric Effect.csv', skiprows=1, names=['Voltage','pecurrent1','pecurrent2','pecurrent3','pecurrent4','pecurrent5','pecurrent6','pecurrent7','pecurrent8','zeroes'])

# %%
# Reformatting data from dp file to np file

data = np.asarray(df)
data.shape

volts = data[:,0]
current365nm = data[:,1]
current405nm = data[:,2]
current436nm = data[:,3]
current486nm = data[:,4]
current546nm = data[:,5]
current577nm = data[:,6]
current589nm = data[:,7]
current656nm = data[:,8]
zeroes = data[:,9]
currents = [current365nm,current405nm,current436nm,current486nm,
            current546nm,current577nm,current589nm,current656nm]

# %%
# Plotting uncorrected data for all wavelengths measured

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected Data')
plt.ylabel('Photoelectric Current (Amps)')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()

plt.plot(df.Voltage, df.pecurrent1, df.Voltage, df.pecurrent2, df.Voltage, df.pecurrent3, df.Voltage, df.pecurrent4, df.Voltage, df.pecurrent5, df.Voltage, df.pecurrent6, df.Voltage, df.pecurrent7, df.Voltage, df.pecurrent8, '-')

# %%
# Plotting uncorrected data for 365nm

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected 365nm')
plt.ylabel('Photoelectric Current (Amps)')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()
plt.plot(df.Voltage,df.pecurrent1, color='violet')
plt.savefig('./v-uncorrected365.svg')

# %%
# Plotting uncorrected data for 405nm

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected 405nm')
plt.ylabel('Photoelectric Current (Amps)')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()
plt.plot(df.Voltage,df.pecurrent2, color='indigo')
plt.savefig('./v-uncorrected405.svg')

# %%
# Plotting uncorrected data for 436nm

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected 436nm')
plt.ylabel('Photoelectric Current')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()
plt.plot(df.Voltage,df.pecurrent3, color='blue')
plt.savefig('./v-uncorrected436.svg')

# %%
# Plotting uncorrected data for 486nm

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected 486nm')
plt.ylabel('Photoelectric Current (Amps)')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()
plt.plot(df.Voltage,current486nm, color='green')
plt.savefig('./v-uncorrected486.svg')

# redo 486nm data collection??

# %%
# Plotting uncorrected data for 546nm

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected 546nm')
plt.ylabel('Photoelectric Current (Amps)')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()
plt.plot(df.Voltage,df.pecurrent5, color='yellow')
plt.savefig('./v-uncorrected546.svg')

# %%
# Plotting uncorrected data for 577nm

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected 577nm')
plt.ylabel('Photoelectric Current')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()
plt.plot(df.Voltage,df.pecurrent6, color='orange')
plt.savefig('./v-uncorrected577.svg')

# %%
# Plotting uncorrected data for 589nm

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected 589nm')
plt.ylabel('Photoelectric Current (Amps)')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()
plt.plot(df.Voltage,df.pecurrent7, color='red')
plt.savefig('./v-uncorrected589.svg')

# %%
# Plotting uncorrected data for 656nm

plt.style.use(['seaborn-pastel'])
plt.title('Uncorrected 656nm')
plt.ylabel('Photoelectric Current (Amps)')
plt.xlabel('Potential (V)')
pylab.xlim(-4, 3)
pylab.ylim(-7E-10,4.2E-8)
plt.grid()
plt.plot(df.Voltage,df.pecurrent8, color='grey')
plt.savefig('./v-uncorrected656.svg')

# %%
# Finding f values for all wavelengths measured

corrected365nm=[]
n=0
while n<701:
    if n == 0:
        i_plus = current365nm[0]
        i_minus = current365nm[700]
    else:
        i_plus = current365nm[n]
        i_minus = current365nm[-n]
    n += 1
    if i_plus > 0:
        f = i_minus / i_plus
    if i_plus < 0:
        f = i_plus / i_minus
    i_corrected = (i_plus - (f*i_minus)) / (1-(f**2))
    print('fraction of correction 365nm: ',f)
    corrected365nm = np.append(corrected365nm, i_corrected)

corrected405nm=[]
n=0
while n<701:
    if n == 0:
        i_plus = current405nm[0]
        i_minus = current405nm[700]
    else:
        i_plus = current405nm[n]
        i_minus = current405nm[-n]
    n += 1
    if i_plus > 0:
        f = i_minus / i_plus
    if i_plus < 0:
        f = i_plus / i_minus
    i_corrected = (i_plus - (f*i_minus)) / (1-(f**2))
    print('fraction of correction 405nm: ',f)
    corrected405nm = np.append(corrected405nm, i_corrected)

corrected436nm=[]
n=0
while n<701:
    if n == 0:
        i_plus = current436nm[0]
        i_minus = current436nm[700]
    else:
        i_plus = current436nm[n]
        i_minus = current436nm[-n]
    n += 1
    if i_plus > 0:
        f = i_minus / i_plus
    if i_plus < 0:
        f = i_plus / i_minus
    i_corrected = (i_plus - (f*i_minus)) / (1-(f**2))
    print('fraction of correction 436nm: ',f)
    corrected436nm = np.append(corrected436nm, i_corrected)

corrected486nm=[]
n=0
while n<701:
    if n == 0:
        i_plus = current486nm[0]
        i_minus = current486nm[700]
    else:
        i_plus = current486nm[n]
        i_minus = current486nm[-n]
    n += 1
    if i_plus > 0:
        f = i_minus / i_plus
    if i_plus < 0:
        f = i_plus / i_minus
    i_corrected = (i_plus - (f*i_minus)) / (1-(f**2))
    print('fraction of correction 486nm: ',f)
    corrected486nm = np.append(corrected486nm, i_corrected)

corrected546nm=[]
n=0
while n<701:
    if n == 0:
        i_plus = current546nm[0]
        i_minus = current546nm[700]
    else:
        i_plus = current546nm[n]
        i_minus = current546nm[-n]
    n += 1
    if i_plus > 0:
        f = i_minus / i_plus
    if i_plus < 0:
        f = i_plus / i_minus
    i_corrected = (i_plus - (f*i_minus)) / (1-(f**2))
    print('fraction of correction 546nm: ',f)
    corrected546nm = np.append(corrected546nm, i_corrected)

corrected577nm=[]
n=0
while n<701:
    if n == 0:
        i_plus = current577nm[0]
        i_minus = current577nm[700]
    else:
        i_plus = current577nm[n]
        i_minus = current577nm[-n]
    n += 1
    if i_plus > 0:
        f = i_minus / i_plus
    if i_plus < 0:
        f = i_plus / i_minus
    i_corrected = (i_plus - (f*i_minus)) / (1-(f**2))
    print('fraction of correction 577nm: ',f)
    corrected577nm = np.append(corrected577nm, i_corrected)

corrected589nm=[]
n=0
while n<701:
    if n == 0:
        i_plus = current589nm[0]
        i_minus = current589nm[700]
    else:
        i_plus = current589nm[n]
        i_minus = current589nm[-n]
    n += 1
    if i_plus > 0:
        f = i_minus / i_plus
    if i_plus < 0:
        f = i_plus / i_minus
    i_corrected = (i_plus - (f*i_minus)) / (1-(f**2))
    print('fraction of correction 589nm: ',f)
    corrected589nm = np.append(corrected589nm, i_corrected)

corrected656nm=[]
n=0
while n<701:
    if n == 0:
        i_plus = current656nm[0]
        i_minus = current656nm[700]
    else:
        i_plus = current656nm[n]
        i_minus = current656nm[-n]
    n += 1
    if i_plus > 0:
        f = i_minus / i_plus
    if i_plus < 0:
        f = i_plus / i_minus
    i_corrected = (i_plus - (f*i_minus)) / (1-(f**2))
    print('fraction of correction 656nm: ',f)
    corrected656nm = np.append(corrected656nm, i_corrected)
# Out:
# fraction of correction 365nm:  -0.002578125
# fraction of correction 365nm:  -0.0024609375
# fraction of correction 365nm:  -0.002401574803149607
# fraction of correction 365nm:  -0.00233201581027668
# fraction of correction 365nm:  -0.002292490118577075
# fraction of correction 365nm:  -0.002292490118577075
# fraction of correction 365nm:  -0.002231075697211156
# fraction of correction 365nm:  -0.0022400000000000002
# fraction of correction 365nm:  -0.0022400000000000002
# fraction of correction 365nm:  -0.0022088353413654616
# fraction of correction 365nm:  -0.002258064516129032
# fraction of correction 365nm:  -0.0023076923076923075
# fraction of correction 365nm:  -0.0022672064777327933
# fraction of correction 365nm:  -0.0022357723577235773
# fraction of correction 365nm:  -0.002244897959183673
# fraction of correction 365nm:  -0.0022540983606557374
# fraction of correction 365nm:  -0.0022131147540983605
# fraction of correction 365nm:  -0.0022222222222222222
# ...

# %%
# Plot showing the corrected current of all wavelengths used

plt.style.use(['seaborn-pastel'])
plt.title('Corrected Data')
plt.ylabel('Photoelectric Current (Amps)')
plt.xlabel('Potential (V)')
plt.grid()
plt.plot(df.Voltage, corrected365nm, df.Voltage, corrected405nm, df.Voltage, corrected436nm, df.Voltage, corrected486nm, df.Voltage, corrected546nm, df.Voltage, corrected577nm, df.Voltage, corrected589nm, df.Voltage, corrected656nm)

# %%
# Polyfit for 365 nm

z365 = np.polyfit(volts, corrected365nm, 8)
zvolt = np.polyfit(volts, zeroes, 1)
p = np.poly1d(z365)
p30 = np.poly1d(np.polyfit(volts, corrected365nm, 30))
xp = np.linspace(-4, 3, 100)
plt.ylim(-1E-8,4E-8)
plt.grid()

plt.title('Potential vs. Photoelectric Current (365nm)')
plt.xlabel('Potential (V)')
plt.ylabel('Photoelectric Current (Amps)')
plt.plot(xp, p(xp), '-', volts, zeroes, 'g--')
plt.savefig('./v-corrected365.svg')

# %%
# Polyfit for 405 nm

z405 = np.polyfit(volts, corrected405nm, 8)
zvolt = np.polyfit(volts, zeroes, 1)
p = np.poly1d(z405)
p30 = np.poly1d(np.polyfit(volts, corrected405nm, 30))
xp = np.linspace(-4, 3, 100)
plt.ylim(-1E-8,4E-8)
plt.grid()

plt.title('Potential vs. Photoelectric Current (405nm)')
plt.xlabel('Potential (V)')
plt.ylabel('Photoelectric Current (Amps)')
plt.plot(xp, p(xp), '-', volts, zeroes, 'g--')
plt.savefig('./v-corrected405.svg')

# %%
# Polyfit for 436 nm

z436 = np.polyfit(volts, corrected436nm, 8)
zvolt = np.polyfit(volts, zeroes, 1)
p = np.poly1d(z436)
p30 = np.poly1d(np.polyfit(volts, corrected436nm, 30))
xp = np.linspace(-4, 3, 100)
plt.ylim(-1E-8,4E-8)
plt.grid()

plt.title('Potential vs. Photoelectric Current (436nm)')
plt.xlabel('Potential (V)')
plt.ylabel('Photoelectric Current (Amps)')
plt.plot(xp, p(xp), '-', volts, zeroes, 'g--')
plt.savefig('./v-corrected436.svg')

# %%
# Polyfit for 486 nm

z486 = np.polyfit(volts, corrected486nm, 8)
zvolt = np.polyfit(volts, zeroes, 1)
p = np.poly1d(z486)
p30 = np.poly1d(np.polyfit(volts, corrected486nm, 30))
xp = np.linspace(-4, 3, 100)
plt.ylim(-1E-8,4E-8)
plt.grid()

plt.title('Potential vs. Photoelectric Current (486nm)')
plt.xlabel('Potential (V)')
plt.ylabel('Photoelectric Current (Amps)')
plt.plot(xp, p(xp), '-', volts, zeroes, 'g--')
plt.savefig('./v-corrected486.svg')

# %%
# Polyfit for 546 nm

z546 = np.polyfit(volts, corrected546nm, 8)
zvolt = np.polyfit(volts, zeroes, 1)
p = np.poly1d(z546)
p30 = np.poly1d(np.polyfit(volts, corrected546nm, 30))
xp = np.linspace(-4, 3, 100)
plt.ylim(-1E-8,4E-8)
plt.grid()

plt.title('Potential vs. Photoelectric Current (546nm)')
plt.xlabel('Potential (V)')
plt.ylabel('Photoelectric Current (Amps)')
plt.plot(xp, p(xp), '-', volts, zeroes, 'g--')
plt.savefig('./v-corrected546.svg')

# %%
# Polyfit for 577 nm

z577 = np.polyfit(volts, corrected577nm, 8)
zvolt = np.polyfit(volts, zeroes, 1)
p = np.poly1d(z577)
p30 = np.poly1d(np.polyfit(volts, corrected577nm, 30))
xp = np.linspace(-4, 3, 100)
plt.ylim(-1E-8,4E-8)
plt.grid()

plt.title('Potential vs. Photoelectric Current (577nm)')
plt.xlabel('Potential (V)')
plt.ylabel('Photoelectric Current (Amps)')
plt.plot(xp, p(xp), '-', volts, zeroes, 'g--')
plt.savefig('./v-corrected577.svg')

# %%
# Polyfit for 589 nm

z589 = np.polyfit(volts, corrected589nm, 8)
zvolt = np.polyfit(volts, zeroes, 1)
p = np.poly1d(z589)
p30 = np.poly1d(np.polyfit(volts, corrected589nm, 30))
xp = np.linspace(-4, 3, 100)
plt.ylim(-1E-8,4E-8)
plt.grid()

plt.title('Potential vs. Photoelectric Current (589nm)')
plt.xlabel('Potential (V)')
plt.ylabel('Photoelectric Current (Amps)')
plt.plot(xp, p(xp), '-', volts, zeroes, 'g--')
plt.savefig('./v-corrected589.svg')

# %%
# Polyfit for 656 nm

z656 = np.polyfit(volts, corrected656nm, 8)
zvolt = np.polyfit(volts, zeroes, 1)
p = np.poly1d(z656)
p30 = np.poly1d(np.polyfit(volts, corrected656nm, 30))
xp = np.linspace(-4, 3, 100)
plt.ylim(-1E-8,4E-8)
plt.grid()

plt.title('Potential vs. Photoelectric Current (656nm)')
plt.xlabel('Potential (V)')
plt.ylabel('Photoelectric Current (Amps)')
plt.plot(xp, p(xp), '-', volts, zeroes, 'g--')
plt.savefig('./v-corrected656.svg')

# %%
# Finding where each line crosses 0 to find the stopping potential for each wavelength measured

print(np.roots(z365).real)
print(np.roots(z405).real)
print(np.roots(z436).real)
print(np.roots(z486).real)
print(np.roots(z546).real)
print(np.roots(z577).real)
print(np.roots(z589).real)
print(np.roots(z656).real)
# Out:
# [ 4.18450777  2.39600344  2.39600344 -4.18668469 -3.79441654 -3.15017073
#  -2.26070926 -1.47178334]
# [ 4.40781824  2.83703808  2.83703808 -3.89523494 -3.44414009 -2.70371893
#  -1.80703925 -1.13008219]
# [ 4.48764264  3.02962539  3.02962539 -3.88929301 -3.41353136 -2.63126641
#  -1.67764095 -0.90109755]
# [ 4.90003341  3.13562435  3.13562435 -3.88336906 -3.38265146 -2.55638537
#  -1.53814119 -0.63752639]
# [ 5.67565914  3.28496132  3.28496132 -3.87970948 -3.36358712 -2.51025483
#  -1.45174891 -0.462384  ]
# [ 9.15517412  3.27755615  3.27755615 -3.87709785 -3.3503884  -2.4799403
#  -1.39944439 -0.37196297]
# [15.5370151   3.22264859  3.22264859 -3.87501829 -3.33999861 -2.45668081
#  -1.36087883 -0.31376588]
# [ 3.21056844  3.21056844 -5.14124174 -4.22641486 -3.05459146 -3.05459146
#  -0.70305563 -0.70305563]

# %%
# Plotting potential and frequency and finding the best linear fit

plt.xlim(4.5E14,8.5E14)
plt.ylim(0,2)
plt.grid()

c = 2.99E8

x_365 = c / 365E-9
x_405 = c / 405E-9
x_436 = c / 436E-9
x_486 = c / 486E-9
x_546 = c / 546E-9
x_577 = c / 577E-9
x_589 = c / 589E-9

# Can drop 656nm data because there is no 656nm spectral line from the mercury lamp
# Light coming from another source from room (overhead lights) causing an interference in data from mercury lamp

x = [x_365, x_405, x_436, x_486, x_546, x_577, x_589]
y = [1.47, 1.13, 0.90, 0.64, 0.46, 0.37, 0.31]


fit = np.polyfit(x,y,1)
fit_fn = np.poly1d(fit) 

plt.plot(x,y, 'bo', x, fit_fn(x), '-k')

# get line of best fit

import scipy
from scipy import stats
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x,y)

plt.title('Stopping Potential vs. Frequency')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Stopping potential (V)')
plt.plot(x,y, 'bo')
plt.show()
plt.savefig('./vs-freq.svg')

# %%
# Finding Planck's constant and the work function of the metal used in the experiment

e = 1.6E-19
h = slope * e

print('slope: ',slope)
print('h: ', h)
print('phi: ',intercept)
# Out:
# slope:  3.615918590431618e-15
# h:  5.785469744690589e-34
# phi:  -1.5350621299151743

# %%
# Error over 10 percent
# Find a valid explanation for the large error in finding Planck's constant

abs(((5.79E-34 - 6.63E-34) / 6.63E-34) * 100)
# Out:
# 12.669683257918555
